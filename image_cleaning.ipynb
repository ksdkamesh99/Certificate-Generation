# %%
cd /content/drive/My Drive/Certificate Generation
# Out:
# /content/drive/My Drive/Certificate Generation

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import sys

# %%
img=cv2.imread('Nonedited.jfif')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img[380:420,460:920,:]=255

# %%
img[500:540,460:920,:]=255

# %%
img[195:220,1000:,:]=252

# %%
plt.imsave("template_final.png",img)
